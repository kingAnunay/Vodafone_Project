# %% [markdown]
# <a href="https://colab.research.google.com/github/kingAnunay/Vodafone_Project/blob/main/SuperStore_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TASK 1 : Identifying and importing essential libraries**

# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt

# %% [markdown]
# **TASK 2 : Data loading and overview**

# %%
# a.Load the dataset from a file
df = pd.read_excel('Superstore.xls')
df
# Out:
#       Row ID        Order ID Order Date  ... Quantity Discount    Profit
# 0          1  CA-2016-152156 2016-11-08  ...        2     0.00   41.9136
# 1          2  CA-2016-152156 2016-11-08  ...        3     0.00  219.5820
# 2          3  CA-2016-138688 2016-06-12  ...        2     0.00    6.8714
# 3          4  US-2015-108966 2015-10-11  ...        5     0.45 -383.0310
# 4          5  US-2015-108966 2015-10-11  ...        2     0.20    2.5164
# ...      ...             ...        ...  ...      ...      ...       ...
# 9989    9990  CA-2014-110422 2014-01-21  ...        3     0.20    4.1028
# 9990    9991  CA-2017-121258 2017-02-26  ...        2     0.00   15.6332
# 9991    9992  CA-2017-121258 2017-02-26  ...        2     0.20   19.3932
# 9992    9993  CA-2017-121258 2017-02-26  ...        4     0.00   13.3200
# 9993    9994  CA-2017-119914 2017-05-04  ...        2     0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
# b.Look at the first 5 records of the data
df.head(5)
# Out:
#    Row ID        Order ID Order Date  ... Quantity Discount    Profit
# 0       1  CA-2016-152156 2016-11-08  ...        2     0.00   41.9136
# 1       2  CA-2016-152156 2016-11-08  ...        3     0.00  219.5820
# 2       3  CA-2016-138688 2016-06-12  ...        2     0.00    6.8714
# 3       4  US-2015-108966 2015-10-11  ...        5     0.45 -383.0310
# 4       5  US-2015-108966 2015-10-11  ...        2     0.20    2.5164
#
# [5 rows x 21 columns]

# %%
# c.Print the columns contained in the data
print(df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# d.Printing count.
count_row = df.shape[0]  
count_col = df.shape[1]
# gives number of Row count
print(count_row)  
# gives number of Col count
print(count_col)
# Out:
# 9994
# 21

# %%
# d.Printing mean
df.mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
# Row ID          4997.500000
# Postal Code    55190.379428
# Sales            229.858001
# Quantity           3.789574
# Discount           0.156203
# Profit            28.656896
# dtype: float64

# %%
# d.Printing mean , max , min, standard deviation etc
#Dropping Postal Code !important
df.drop(['Postal Code'],axis=1).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Row ID      4997.500000
# Sales        229.858001
# Quantity       3.789574
# Discount       0.156203
# Profit        28.656896
# dtype: float64

# %%
# d.Printing max

df.max()
# Out:
# Row ID                                         9994
# Order ID                             US-2017-169551
# Order Date                      2017-12-30 00:00:00
# Ship Date                       2018-01-05 00:00:00
# Ship Mode                            Standard Class
# Customer ID                                ZD-21925
# Customer Name                    Zuschuss Donatelli
# Segment                                 Home Office
# Country                               United States
# City                                           Yuma
# State                                       Wyoming
# Postal Code                                   99301
# Region                                         West
# Product ID                          TEC-PH-10004977
# Category                                 Technology
# Sub-Category                                 Tables
# Product Name     netTALK DUO VoIP Telephone Service
# Sales                                       22638.5
# Quantity                                         14
# Discount                                        0.8
# Profit                                      8399.98
# dtype: object

# %%
# d.Printing max
# Only Selecting Sales,Quantity,Discount,Profit as they are only relevant when it comes to max.
df[['Sales','Quantity','Discount','Profit']].max()
# Out:
# Sales       22638.480
# Quantity       14.000
# Discount        0.800
# Profit       8399.976
# dtype: float64

# %%
# d.Printing min
df.min()
# Out:
# Row ID                                                           1
# Order ID                                            CA-2014-100006
# Order Date                                     2014-01-03 00:00:00
# Ship Date                                      2014-01-07 00:00:00
# Ship Mode                                              First Class
# Customer ID                                               AA-10315
# Customer Name                                        Aaron Bergman
# Segment                                                   Consumer
# Country                                              United States
# City                                                      Aberdeen
# State                                                      Alabama
# Postal Code                                                   1040
# Region                                                     Central
# Product ID                                         FUR-BO-10000112
# Category                                                 Furniture
# Sub-Category                                           Accessories
# Product Name     "While you Were Out" Message Book, One Form pe...
# Sales                                                        0.444
# Quantity                                                         1
# Discount                                                         0
# Profit                                                    -6599.98
# dtype: object

# %%
# d.Printing min
# Only Selecting Sales,Quantity,Discount,Profit as they are only relevant when it comes to max.
df[['Sales','Quantity','Discount','Profit']].min()
# Out:
# Sales          0.444
# Quantity       1.000
# Discount       0.000
# Profit     -6599.978
# dtype: float64

# %%
# d.Printing standard deviation
df.std(axis = 0, skipna = True)
# Out:
# Row ID          2885.163629
# Postal Code    32063.693350
# Sales            623.245101
# Quantity           2.225110
# Discount           0.206452
# Profit           234.260108
# dtype: float64

# %%
# e.Find out are there any missing or null values in the data for all columns
df.isnull()
# Out:
#       Row ID  Order ID  Order Date  ...  Quantity  Discount  Profit
# 0      False     False       False  ...     False     False   False
# 1      False     False       False  ...     False     False   False
# 2      False     False       False  ...     False     False   False
# 3      False     False       False  ...     False     False   False
# 4      False     False       False  ...     False     False   False
# ...      ...       ...         ...  ...       ...       ...     ...
# 9989   False     False       False  ...     False     False   False
# 9990   False     False       False  ...     False     False   False
# 9991   False     False       False  ...     False     False   False
# 9992   False     False       False  ...     False     False   False
# 9993   False     False       False  ...     False     False   False
#
# [9994 rows x 21 columns]

# %%
# e.Find out are there any missing or null values in the data for all columns
# Visualize missing values as a matrix 
msno.matrix(df)

# %% [markdown]
# **TASK 3 : Find out the per unit price from the data**

# %%
# a. Convert date time field into pandas time object
#Finding date time fields
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
# a. Convert date time field into pandas time object
# Date time fields : Ship date and Order date

# Could be an Error Here : Start
# df['Order Date'] = df['Order Date'].astype('')
# df['Ship Date'] = df['Ship Date'].astype('')
# Could be an Error Here : End

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
# b. Find out the price per unit from the data and create a column for it in the same data

df['Unit Price'] = df.apply(lambda row: (row.Sales / row.Quantity), axis = 1)
df
# Out:
#       Row ID        Order ID Order Date  ... Discount    Profit Unit Price
# 0          1  CA-2016-152156 2016-11-08  ...     0.00   41.9136   130.9800
# 1          2  CA-2016-152156 2016-11-08  ...     0.00  219.5820   243.9800
# 2          3  CA-2016-138688 2016-06-12  ...     0.00    6.8714     7.3100
# 3          4  US-2015-108966 2015-10-11  ...     0.45 -383.0310   191.5155
# 4          5  US-2015-108966 2015-10-11  ...     0.20    2.5164    11.1840
# ...      ...             ...        ...  ...      ...       ...        ...
# 9989    9990  CA-2014-110422 2014-01-21  ...     0.20    4.1028     8.4160
# 9990    9991  CA-2017-121258 2017-02-26  ...     0.00   15.6332    45.9800
# 9991    9992  CA-2017-121258 2017-02-26  ...     0.20   19.3932   129.2880
# 9992    9993  CA-2017-121258 2017-02-26  ...     0.00   13.3200     7.4000
# 9993    9994  CA-2017-119914 2017-05-04  ...     0.00   72.9480   121.5800
#
# [9994 rows x 22 columns]

# %% [markdown]
# **TASK 4 : Find out the monthly revenue and analyze the findings**

# %%
df.sum()
# Out:
# Row ID                                                    49945015
# Order ID         CA-2016-152156CA-2016-152156CA-2016-138688US-2...
# Ship Mode        Second ClassSecond ClassSecond ClassStandard C...
# Customer ID      CG-12520CG-12520DV-13045SO-20335SO-20335BH-117...
# Customer Name    Claire GuteClaire GuteDarrin Van HuffSean O'Do...
# Segment          ConsumerConsumerCorporateConsumerConsumerConsu...
# Country          United StatesUnited StatesUnited StatesUnited ...
# City             HendersonHendersonLos AngelesFort LauderdaleFo...
# State            KentuckyKentuckyCaliforniaFloridaFloridaCalifo...
# Postal Code                                              551572652
# Region           SouthSouthWestSouthSouthWestWestWestWestWestWe...
# Product ID       FUR-BO-10001798FUR-CH-10000454OFF-LA-10000240F...
# Category         FurnitureFurnitureOffice SuppliesFurnitureOffi...
# Sub-Category     BookcasesChairsLabelsTablesStorageFurnishingsA...
# Product Name     Bush Somerset Collection BookcaseHon Deluxe Fa...
# Sales                                                   2.2972e+06
# Quantity                                                     37873
# Discount                                                   1561.09
# Profit                                                      286397
# Unit Price                                                  608830
# dtype: object

# %%
df[['Profit']].sum()
# Out:
# Profit    286397.0217
# dtype: float64

# %%
# a.Create a column with Year and month field only give a suitable name to it

df1 = df[['Ship Date']].copy()
df1
# Out:
#       Ship Date
# 0    2016-11-11
# 1    2016-11-11
# 2    2016-06-16
# 3    2015-10-18
# 4    2015-10-18
# ...         ...
# 9989 2014-01-23
# 9990 2017-03-03
# 9991 2017-03-03
# 9992 2017-03-03
# 9993 2017-05-09
#
# [9994 rows x 1 columns]

# %%
df1['Year'] = pd.DatetimeIndex(df1['Ship Date']).year
df1['Month'] = pd.DatetimeIndex(df1['Ship Date']).month
# df1.drop(['Ship Date'],axis=0)
del df1['Ship Date']
# df1['Revenue'] = df[['Profit']].copy()
df1
# Out:
#       Year  Month
# 0     2016     11
# 1     2016     11
# 2     2016      6
# 3     2015     10
# 4     2015     10
# ...    ...    ...
# 9989  2014      1
# 9990  2017      3
# 9991  2017      3
# 9992  2017      3
# 9993  2017      5
#
# [9994 rows x 2 columns]

# %%
df1['Time'] = pd.to_datetime(df1[['Year', 'Month']].assign(DAY=1)).dt.to_period('M')
del df1['Year']
del df1['Month']
df1['Revenue'] = df[['Profit']].copy()
df1
# Out:
#          Time   Revenue
# 0     2016-11   41.9136
# 1     2016-11  219.5820
# 2     2016-06    6.8714
# 3     2015-10 -383.0310
# 4     2015-10    2.5164
# ...       ...       ...
# 9989  2014-01    4.1028
# 9990  2017-03   15.6332
# 9991  2017-03   19.3932
# 9992  2017-03   13.3200
# 9993  2017-05   72.9480
#
# [9994 rows x 2 columns]

# %%
# b.Create a separate dataset from the data which will have two columns , one which is created in step a of this task and second the monthly sales / revenue

# df1['Year-Month'] = df1['Year'].astype(str) + df1['Month']
# df1['Year-Month'] = df1['Year'].str.cat(df1['Month'],sep=" ")
df1
# Out:
#          Time   Revenue
# 0     2016-11   41.9136
# 1     2016-11  219.5820
# 2     2016-06    6.8714
# 3     2015-10 -383.0310
# 4     2015-10    2.5164
# ...       ...       ...
# 9989  2014-01    4.1028
# 9990  2017-03   15.6332
# 9991  2017-03   19.3932
# 9992  2017-03   13.3200
# 9993  2017-05   72.9480
#
# [9994 rows x 2 columns]

# %%
#  b.Create a separate dataset from the data which will have two columns , one which is created in step a of this task and second the monthly sales / revenue

df2 = df1.groupby('Time')['Revenue'].sum()
df2
# Out:
# Time
# 2014-01     2424.1125
# 2014-02      866.1925
# 2014-03      123.4122
# 2014-04     3313.2568
# 2014-05     2636.2171
# 2014-06     5316.8660
# 2014-07    -1047.8993
# 2014-08     6161.5346
# 2014-09     6835.8856
# 2014-10     4567.7754
# 2014-11     9415.3468
# 2014-12     6680.0253
# 2015-01    -1455.5695
# 2015-02     3158.6857
# 2015-03     9762.9141
# 2015-04     1558.4000
# 2015-05     5562.9605
# 2015-06     5222.5484
# 2015-07     2940.2336
# 2015-08     3650.4602
# 2015-09     8713.5774
# 2015-10     3601.8000
# 2015-11    12362.3376
# 2015-12     7803.1819
# 2016-01     3445.7653
# 2016-02     5274.3035
# 2016-03     3718.0314
# 2016-04     2831.8084
# 2016-05     6356.6381
# 2016-06     6663.7107
# 2016-07     4801.1517
# 2016-08     2076.1467
# 2016-09     9359.3231
# 2016-10    15629.3249
# 2016-11    11669.3287
# 2016-12    11115.5692
# 2017-01     6359.2081
# 2017-02     2058.0360
# 2017-03    13157.4265
# 2017-04     2678.0235
# 2017-05     5910.0197
# 2017-06     7195.1466
# 2017-07     6639.3986
# 2017-08    10155.0590
# 2017-09    11237.4753
# 2017-10     8825.8434
# 2017-11     8689.7765
# 2017-12     9441.4620
# 2018-01      934.7894
# Freq: M, Name: Revenue, dtype: float64

# %%
#  b.Create a separate dataset from the data which will have two columns , one which is created in step a of this task and second the monthly sales / revenue
columns = ['Revenue']
# df3['Time'] = df3.index
df3 = pd.DataFrame(df2, columns=columns)
df3['Time'] = df3.index
df3
# Out:
#             Revenue     Time
# Time
# 2014-01   2424.1125  2014-01
# 2014-02    866.1925  2014-02
# 2014-03    123.4122  2014-03
# 2014-04   3313.2568  2014-04
# 2014-05   2636.2171  2014-05
# 2014-06   5316.8660  2014-06
# 2014-07  -1047.8993  2014-07
# 2014-08   6161.5346  2014-08
# 2014-09   6835.8856  2014-09
# 2014-10   4567.7754  2014-10
# 2014-11   9415.3468  2014-11
# 2014-12   6680.0253  2014-12
# 2015-01  -1455.5695  2015-01
# 2015-02   3158.6857  2015-02
# 2015-03   9762.9141  2015-03
# 2015-04   1558.4000  2015-04
# 2015-05   5562.9605  2015-05
# 2015-06   5222.5484  2015-06
# 2015-07   2940.2336  2015-07
# 2015-08   3650.4602  2015-08
# 2015-09   8713.5774  2015-09
# 2015-10   3601.8000  2015-10
# 2015-11  12362.3376  2015-11
# 2015-12   7803.1819  2015-12
# 2016-01   3445.7653  2016-01
# 2016-02   5274.3035  2016-02
# 2016-03   3718.0314  2016-03
# 2016-04   2831.8084  2016-04
# 2016-05   6356.6381  2016-05
# 2016-06   6663.7107  2016-06
# 2016-07   4801.1517  2016-07
# 2016-08   2076.1467  2016-08
# 2016-09   9359.3231  2016-09
# 2016-10  15629.3249  2016-10
# 2016-11  11669.3287  2016-11
# 2016-12  11115.5692  2016-12
# 2017-01   6359.2081  2017-01
# 2017-02   2058.0360  2017-02
# 2017-03  13157.4265  2017-03
# 2017-04   2678.0235  2017-04
# 2017-05   5910.0197  2017-05
# 2017-06   7195.1466  2017-06
# 2017-07   6639.3986  2017-07
# 2017-08  10155.0590  2017-08
# 2017-09  11237.4753  2017-09
# 2017-10   8825.8434  2017-10
# 2017-11   8689.7765  2017-11
# 2017-12   9441.4620  2017-12
# 2018-01    934.7894  2018-01

# %%
#  b.Create a separate dataset from the data which will have two columns , one which is created in step a of this task and second the monthly sales / revenue
df3 = df3[['Time', 'Revenue']]
df3
# Out:
#             Time     Revenue
# Time
# 2014-01  2014-01   2424.1125
# 2014-02  2014-02    866.1925
# 2014-03  2014-03    123.4122
# 2014-04  2014-04   3313.2568
# 2014-05  2014-05   2636.2171
# 2014-06  2014-06   5316.8660
# 2014-07  2014-07  -1047.8993
# 2014-08  2014-08   6161.5346
# 2014-09  2014-09   6835.8856
# 2014-10  2014-10   4567.7754
# 2014-11  2014-11   9415.3468
# 2014-12  2014-12   6680.0253
# 2015-01  2015-01  -1455.5695
# 2015-02  2015-02   3158.6857
# 2015-03  2015-03   9762.9141
# 2015-04  2015-04   1558.4000
# 2015-05  2015-05   5562.9605
# 2015-06  2015-06   5222.5484
# 2015-07  2015-07   2940.2336
# 2015-08  2015-08   3650.4602
# 2015-09  2015-09   8713.5774
# 2015-10  2015-10   3601.8000
# 2015-11  2015-11  12362.3376
# 2015-12  2015-12   7803.1819
# 2016-01  2016-01   3445.7653
# 2016-02  2016-02   5274.3035
# 2016-03  2016-03   3718.0314
# 2016-04  2016-04   2831.8084
# 2016-05  2016-05   6356.6381
# 2016-06  2016-06   6663.7107
# 2016-07  2016-07   4801.1517
# 2016-08  2016-08   2076.1467
# 2016-09  2016-09   9359.3231
# 2016-10  2016-10  15629.3249
# 2016-11  2016-11  11669.3287
# 2016-12  2016-12  11115.5692
# 2017-01  2017-01   6359.2081
# 2017-02  2017-02   2058.0360
# 2017-03  2017-03  13157.4265
# 2017-04  2017-04   2678.0235
# 2017-05  2017-05   5910.0197
# 2017-06  2017-06   7195.1466
# 2017-07  2017-07   6639.3986
# 2017-08  2017-08  10155.0590
# 2017-09  2017-09  11237.4753
# 2017-10  2017-10   8825.8434
# 2017-11  2017-11   8689.7765
# 2017-12  2017-12   9441.4620
# 2018-01  2018-01    934.7894

# %%
#  b.Create a separate dataset from the data which will have two columns , one which is created in step a of this task and second the monthly sales / revenue
# df3.reset_index(inplace=True)
# df3.index = pd.RangeIndex(start=0, stop=49, step=1)

# %%
# b.Create a separate dataset from the data which will have two columns , one which is created in step a of this task and second the monthly sales / revenue
df3
# Out:
#             Time     Revenue
# Time
# 2014-01  2014-01   2424.1125
# 2014-02  2014-02    866.1925
# 2014-03  2014-03    123.4122
# 2014-04  2014-04   3313.2568
# 2014-05  2014-05   2636.2171
# 2014-06  2014-06   5316.8660
# 2014-07  2014-07  -1047.8993
# 2014-08  2014-08   6161.5346
# 2014-09  2014-09   6835.8856
# 2014-10  2014-10   4567.7754
# 2014-11  2014-11   9415.3468
# 2014-12  2014-12   6680.0253
# 2015-01  2015-01  -1455.5695
# 2015-02  2015-02   3158.6857
# 2015-03  2015-03   9762.9141
# 2015-04  2015-04   1558.4000
# 2015-05  2015-05   5562.9605
# 2015-06  2015-06   5222.5484
# 2015-07  2015-07   2940.2336
# 2015-08  2015-08   3650.4602
# 2015-09  2015-09   8713.5774
# 2015-10  2015-10   3601.8000
# 2015-11  2015-11  12362.3376
# 2015-12  2015-12   7803.1819
# 2016-01  2016-01   3445.7653
# 2016-02  2016-02   5274.3035
# 2016-03  2016-03   3718.0314
# 2016-04  2016-04   2831.8084
# 2016-05  2016-05   6356.6381
# 2016-06  2016-06   6663.7107
# 2016-07  2016-07   4801.1517
# 2016-08  2016-08   2076.1467
# 2016-09  2016-09   9359.3231
# 2016-10  2016-10  15629.3249
# 2016-11  2016-11  11669.3287
# 2016-12  2016-12  11115.5692
# 2017-01  2017-01   6359.2081
# 2017-02  2017-02   2058.0360
# 2017-03  2017-03  13157.4265
# 2017-04  2017-04   2678.0235
# 2017-05  2017-05   5910.0197
# 2017-06  2017-06   7195.1466
# 2017-07  2017-07   6639.3986
# 2017-08  2017-08  10155.0590
# 2017-09  2017-09  11237.4753
# 2017-10  2017-10   8825.8434
# 2017-11  2017-11   8689.7765
# 2017-12  2017-12   9441.4620
# 2018-01  2018-01    934.7894

# %%
# c.Plot this dataset
df3.plot()
plt.savefig("Monthly_Revenue.svg")

# %%
# c.Plot this dataset
df3.plot.bar();
plt.savefig("Monthly_Revenue_Bar.svg")

# %% [markdown]
# d.Describe your analysis for the monthly revenue observations.
#
# ---
#
#
# > Most Generated Revenue in 2016 October.
#
# ---
#
#
# > Revenue is kinda constant More or less.
#
#
# ---

# %% [markdown]
# **TASK 5 : Find out the yearly revenue and analyze the findings**

# %%
# df4['Time'] = pd.to_datetime(df1[['Year']].assign(DAY=1)).dt.to_period('Y')
# a.Create a column with Year field only give a suitable name to it
df3
# Out:
#             Time     Revenue
# Time
# 2014-01  2014-01   2424.1125
# 2014-02  2014-02    866.1925
# 2014-03  2014-03    123.4122
# 2014-04  2014-04   3313.2568
# 2014-05  2014-05   2636.2171
# 2014-06  2014-06   5316.8660
# 2014-07  2014-07  -1047.8993
# 2014-08  2014-08   6161.5346
# 2014-09  2014-09   6835.8856
# 2014-10  2014-10   4567.7754
# 2014-11  2014-11   9415.3468
# 2014-12  2014-12   6680.0253
# 2015-01  2015-01  -1455.5695
# 2015-02  2015-02   3158.6857
# 2015-03  2015-03   9762.9141
# 2015-04  2015-04   1558.4000
# 2015-05  2015-05   5562.9605
# 2015-06  2015-06   5222.5484
# 2015-07  2015-07   2940.2336
# 2015-08  2015-08   3650.4602
# 2015-09  2015-09   8713.5774
# 2015-10  2015-10   3601.8000
# 2015-11  2015-11  12362.3376
# 2015-12  2015-12   7803.1819
# 2016-01  2016-01   3445.7653
# 2016-02  2016-02   5274.3035
# 2016-03  2016-03   3718.0314
# 2016-04  2016-04   2831.8084
# 2016-05  2016-05   6356.6381
# 2016-06  2016-06   6663.7107
# 2016-07  2016-07   4801.1517
# 2016-08  2016-08   2076.1467
# 2016-09  2016-09   9359.3231
# 2016-10  2016-10  15629.3249
# 2016-11  2016-11  11669.3287
# 2016-12  2016-12  11115.5692
# 2017-01  2017-01   6359.2081
# 2017-02  2017-02   2058.0360
# 2017-03  2017-03  13157.4265
# 2017-04  2017-04   2678.0235
# 2017-05  2017-05   5910.0197
# 2017-06  2017-06   7195.1466
# 2017-07  2017-07   6639.3986
# 2017-08  2017-08  10155.0590
# 2017-09  2017-09  11237.4753
# 2017-10  2017-10   8825.8434
# 2017-11  2017-11   8689.7765
# 2017-12  2017-12   9441.4620
# 2018-01  2018-01    934.7894

# %%
# a.Create a column with Year field only give a suitable name to it
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 49 entries, 2014-01 to 2018-01
# Freq: M
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Time     49 non-null     period[M]
#  1   Revenue  49 non-null     float64
# dtypes: float64(1), period[M](1)
# memory usage: 1.1 KB

# %%
# a.Create a column with Year field only give a suitable name to it
df1
# Out:
#          Time   Revenue
# 0     2016-11   41.9136
# 1     2016-11  219.5820
# 2     2016-06    6.8714
# 3     2015-10 -383.0310
# 4     2015-10    2.5164
# ...       ...       ...
# 9989  2014-01    4.1028
# 9990  2017-03   15.6332
# 9991  2017-03   19.3932
# 9992  2017-03   13.3200
# 9993  2017-05   72.9480
#
# [9994 rows x 2 columns]

# %%
# a.Create a column with Year field only give a suitable name to it
df4 = df[['Ship Date']].copy()
df4['Years'] = pd.DatetimeIndex(df4['Ship Date']).year
# df4['Month'] = pd.DatetimeIndex(df1['Ship Date']).month
df4['Year'] = pd.to_datetime(df4[['Years']].assign(DAY=1).assign(MONTH=1)).dt.to_period('Y')
del df4['Ship Date']
del df4['Years']
df4['Revenue'] = df[['Profit']].copy()
df4
# Out:
#       Year   Revenue
# 0     2016   41.9136
# 1     2016  219.5820
# 2     2016    6.8714
# 3     2015 -383.0310
# 4     2015    2.5164
# ...    ...       ...
# 9989  2014    4.1028
# 9990  2017   15.6332
# 9991  2017   19.3932
# 9992  2017   13.3200
# 9993  2017   72.9480
#
# [9994 rows x 2 columns]

# %%
# a.Create a column with Year field only give a suitable name to it
df5 = df4.groupby('Year')['Revenue'].sum()
df5
# Out:
# Year
# 2014    47292.7255
# 2015    62881.5299
# 2016    82941.1017
# 2017    92346.8752
# 2018      934.7894
# Freq: A-DEC, Name: Revenue, dtype: float64

# %%
# b.Create a separate dataset from the data which will have two columns , one which is created in step a of this task and second the yearly sales / revenue
columns = ['Revenue']
# df3['Time'] = df3.index
df6 = pd.DataFrame(df5, columns=columns)
df6['Time'] = df6.index
df6
# Out:
#          Revenue  Time
# Year
# 2014  47292.7255  2014
# 2015  62881.5299  2015
# 2016  82941.1017  2016
# 2017  92346.8752  2017
# 2018    934.7894  2018

# %%
# b.Create a separate dataset from the data which will have two columns , one which is created in step a of this task and second the yearly sales / revenue
df6 = df6[['Time', 'Revenue']]
df6
# Out:
#       Time     Revenue
# Year
# 2014  2014  47292.7255
# 2015  2015  62881.5299
# 2016  2016  82941.1017
# 2017  2017  92346.8752
# 2018  2018    934.7894

# %%
# c.Plot this dataset
df6.plot()
plt.savefig("Yearly_Revenue.svg")

# %%
# c.Plot this dataset
df6.plot.bar();
plt.savefig("Yearly_Revenue_Bar.svg")

# %% [markdown]
# d.Describe your analysis for the yearly revenue observations.
#
# ---
#
#
# > Most Generated Revenue in 2017 October.
#
# ---
#
#
# > Company has seen constant growth.However,2018 has been a bad year.
#
#
# ---

# %% [markdown]
# **TASK 6 : Finding out the monthly growth rate and analyse the findings**

# %%
# a.Create a column in the monthly revenue dataset for monthly growth rate

df3
# Out:
#             Time     Revenue
# Time
# 2014-01  2014-01   2424.1125
# 2014-02  2014-02    866.1925
# 2014-03  2014-03    123.4122
# 2014-04  2014-04   3313.2568
# 2014-05  2014-05   2636.2171
# 2014-06  2014-06   5316.8660
# 2014-07  2014-07  -1047.8993
# 2014-08  2014-08   6161.5346
# 2014-09  2014-09   6835.8856
# 2014-10  2014-10   4567.7754
# 2014-11  2014-11   9415.3468
# 2014-12  2014-12   6680.0253
# 2015-01  2015-01  -1455.5695
# 2015-02  2015-02   3158.6857
# 2015-03  2015-03   9762.9141
# 2015-04  2015-04   1558.4000
# 2015-05  2015-05   5562.9605
# 2015-06  2015-06   5222.5484
# 2015-07  2015-07   2940.2336
# 2015-08  2015-08   3650.4602
# 2015-09  2015-09   8713.5774
# 2015-10  2015-10   3601.8000
# 2015-11  2015-11  12362.3376
# 2015-12  2015-12   7803.1819
# 2016-01  2016-01   3445.7653
# 2016-02  2016-02   5274.3035
# 2016-03  2016-03   3718.0314
# 2016-04  2016-04   2831.8084
# 2016-05  2016-05   6356.6381
# 2016-06  2016-06   6663.7107
# 2016-07  2016-07   4801.1517
# 2016-08  2016-08   2076.1467
# 2016-09  2016-09   9359.3231
# 2016-10  2016-10  15629.3249
# 2016-11  2016-11  11669.3287
# 2016-12  2016-12  11115.5692
# 2017-01  2017-01   6359.2081
# 2017-02  2017-02   2058.0360
# 2017-03  2017-03  13157.4265
# 2017-04  2017-04   2678.0235
# 2017-05  2017-05   5910.0197
# 2017-06  2017-06   7195.1466
# 2017-07  2017-07   6639.3986
# 2017-08  2017-08  10155.0590
# 2017-09  2017-09  11237.4753
# 2017-10  2017-10   8825.8434
# 2017-11  2017-11   8689.7765
# 2017-12  2017-12   9441.4620
# 2018-01  2018-01    934.7894

# %%
# a.Create a column in the monthly revenue dataset for monthly growth rate
# df['Growth Rate %'] = df.apply(lambda row: ((row.Profit / (row.Sales - row.Profit))*100), axis = 1)
# df
df3['Growth Rate'] = df3['Revenue'].pct_change()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# a.Create a column in the monthly revenue dataset for monthly growth rate
df3
# Out:
#             Time     Revenue  Growth Rate
# Time
# 2014-01  2014-01   2424.1125          NaN
# 2014-02  2014-02    866.1925    -0.642676
# 2014-03  2014-03    123.4122    -0.857523
# 2014-04  2014-04   3313.2568    25.847077
# 2014-05  2014-05   2636.2171    -0.204343
# 2014-06  2014-06   5316.8660     1.016854
# 2014-07  2014-07  -1047.8993    -1.197090
# 2014-08  2014-08   6161.5346    -6.879892
# 2014-09  2014-09   6835.8856     0.109445
# 2014-10  2014-10   4567.7754    -0.331795
# 2014-11  2014-11   9415.3468     1.061254
# 2014-12  2014-12   6680.0253    -0.290517
# 2015-01  2015-01  -1455.5695    -1.217899
# 2015-02  2015-02   3158.6857    -3.170069
# 2015-03  2015-03   9762.9141     2.090815
# 2015-04  2015-04   1558.4000    -0.840376
# 2015-05  2015-05   5562.9605     2.569662
# 2015-06  2015-06   5222.5484    -0.061193
# 2015-07  2015-07   2940.2336    -0.437012
# 2015-08  2015-08   3650.4602     0.241554
# 2015-09  2015-09   8713.5774     1.386981
# 2015-10  2015-10   3601.8000    -0.586645
# 2015-11  2015-11  12362.3376     2.432267
# 2015-12  2015-12   7803.1819    -0.368794
# 2016-01  2016-01   3445.7653    -0.558415
# 2016-02  2016-02   5274.3035     0.530662
# 2016-03  2016-03   3718.0314    -0.295067
# 2016-04  2016-04   2831.8084    -0.238358
# 2016-05  2016-05   6356.6381     1.244727
# 2016-06  2016-06   6663.7107     0.048307
# 2016-07  2016-07   4801.1517    -0.279508
# 2016-08  2016-08   2076.1467    -0.567573
# 2016-09  2016-09   9359.3231     3.508026
# 2016-10  2016-10  15629.3249     0.669920
# 2016-11  2016-11  11669.3287    -0.253370
# 2016-12  2016-12  11115.5692    -0.047454
# 2017-01  2017-01   6359.2081    -0.427901
# 2017-02  2017-02   2058.0360    -0.676369
# 2017-03  2017-03  13157.4265     5.393196
# 2017-04  2017-04   2678.0235    -0.796463
# 2017-05  2017-05   5910.0197     1.206859
# 2017-06  2017-06   7195.1466     0.217449
# 2017-07  2017-07   6639.3986    -0.077239
# 2017-08  2017-08  10155.0590     0.529515
# 2017-09  2017-09  11237.4753     0.106589
# 2017-10  2017-10   8825.8434    -0.214606
# 2017-11  2017-11   8689.7765    -0.015417
# 2017-12  2017-12   9441.4620     0.086502
# 2018-01  2018-01    934.7894    -0.900991

# %%
# b.Find out the maximum monthly growth rate
df3['Growth Rate'].max()
# Out:
# 25.84707670716552

# %%
# c.Plot the findings
df3['Growth Rate'].plot()

# %% [markdown]
# d.Describe the findings
#
# ---
# max growth rate reached in Start of 2014
#
# ---
#
# was all time low mid 2014
#
# ---
# now the condition isn't so good compared to 2015-2017.

# %% [markdown]
# **TASK 7 : Finding out the most and least sold product id**

# %%
df
# Out:
#       Row ID        Order ID Order Date  ... Unit Price Growth Rate Growth Rate %
# 0          1  CA-2016-152156 2016-11-08  ...   130.9800   19.047619     19.047619
# 1          2  CA-2016-152156 2016-11-08  ...   243.9800   42.857143     42.857143
# 2          3  CA-2016-138688 2016-06-12  ...     7.3100   88.679245     88.679245
# 3          4  US-2015-108966 2015-10-11  ...   191.5155  -28.571429    -28.571429
# 4          5  US-2015-108966 2015-10-11  ...    11.1840   12.676056     12.676056
# ...      ...             ...        ...  ...        ...         ...           ...
# 9989    9990  CA-2014-110422 2014-01-21  ...     8.4160   19.402985     19.402985
# 9990    9991  CA-2017-121258 2017-02-26  ...    45.9800   20.481928     20.481928
# 9991    9992  CA-2017-121258 2017-02-26  ...   129.2880    8.108108      8.108108
# 9992    9993  CA-2017-121258 2017-02-26  ...     7.4000   81.818182     81.818182
# 9993    9994  CA-2017-119914 2017-05-04  ...   121.5800   42.857143     42.857143
#
# [9994 rows x 24 columns]

# %%
# a.Create a new dataset including the product ids and total quantities sold for that id

df7 = df.groupby('Product ID')['Quantity'].sum()
df7
# Out:
# Product ID
# FUR-BO-10000112     9
# FUR-BO-10000330    10
# FUR-BO-10000362    14
# FUR-BO-10000468    21
# FUR-BO-10000711    12
#                    ..
# TEC-PH-10004912    11
# TEC-PH-10004922    19
# TEC-PH-10004924     8
# TEC-PH-10004959     4
# TEC-PH-10004977    32
# Name: Quantity, Length: 1862, dtype: int64

# %%
# b.Find out the most sold product from the created dataset
df7.idxmax()
# Out:
# 'TEC-AC-10003832'

# %% [markdown]
# **TASK 8 : Finding out the customer who bought most and least from us in terms of quantity**

# %%
# a.Create a dataset containing name and quantities bought
df8 = df.groupby('Customer Name')['Quantity'].sum()
df8
# Out:
# Customer Name
# Aaron Bergman          13
# Aaron Hawkins          54
# Aaron Smayling         48
# Adam Bellavance        56
# Adam Hart              75
#                      ...
# Xylona Preis          100
# Yana Sorensen          58
# Yoseph Carroll         31
# Zuschuss Carroll      105
# Zuschuss Donatelli     32
# Name: Quantity, Length: 793, dtype: int64

# %%
# b.Find out the customer name and quantity, who bought maximum in quantity
df8.idxmax()
# Out:
# 'Jonathan Doherty'

# %%
# b.Find out the customer name and quantity, who bought maximum in quantity
df8.max()
# Out:
# 150

# %% [markdown]
# **TASK 9 : Finding out the customer who bought most and least from us in terms of value**

# %%
# a.Create a dataset containing name and sales generated by him
df9 = df.groupby('Customer Name')['Sales'].sum()
df9
# Out:
# Customer Name
# Aaron Bergman          886.156
# Aaron Hawkins         1744.700
# Aaron Smayling        3050.692
# Adam Bellavance       7755.620
# Adam Hart             3250.337
#                         ...
# Xylona Preis          2374.658
# Yana Sorensen         6720.444
# Yoseph Carroll        5454.350
# Zuschuss Carroll      8025.707
# Zuschuss Donatelli    1493.944
# Name: Sales, Length: 793, dtype: float64

# %%
# b.Find out the customer name and sales, who bought maximum in value
df9.idxmax()
# Out:
# 'Sean Miller'

# %%
# b.Find out the customer name and sales, who bought maximum in value
df9.max()
# Out:
# 25043.05

# %% [markdown]
# **TASK 10 :
# Finding out the majority and minority customer cities on basis of**

# %%
# a. Number of customers
df10 = df.pivot_table(index=['City'], aggfunc='size')
df10
# Out:
# City
# Aberdeen        1
# Abilene         1
# Akron          21
# Albuquerque    14
# Alexandria     16
#                ..
# Woonsocket      4
# Yonkers        15
# York            5
# Yucaipa         1
# Yuma            4
# Length: 531, dtype: int64

# %%
# a. Number of customers
df10.idxmax()
# Out:
# 'New York City'

# %%
# b. Sales value
df11 = df.groupby('City')['Sales'].sum()
df11
# Out:
# City
# Aberdeen         25.500
# Abilene           1.392
# Akron          2729.986
# Albuquerque    2220.160
# Alexandria     5519.570
#                  ...
# Woonsocket      195.550
# Yonkers        7657.666
# York            817.978
# Yucaipa          50.800
# Yuma            840.865
# Name: Sales, Length: 531, dtype: float64

# %%
# b. Sales value
df11.idxmax()
# Out:
# 'New York City'

# %%
# c. Number of quantity sold
df12 = df.groupby('City')['Quantity'].sum()
df12
# Out:
# City
# Aberdeen        3
# Abilene         2
# Akron          65
# Albuquerque    65
# Alexandria     84
#                ..
# Woonsocket     15
# Yonkers        57
# York           19
# Yucaipa         5
# Yuma           22
# Name: Quantity, Length: 531, dtype: int64

# %%
# c. Number of quantity sold
df12.idxmax()
# Out:
# 'New York City'

# %% [markdown]
# **TASK 11 : Find out the most and least sold product category from the store**

# %%
# a.Value based
df13 = df.groupby('Category')['Sales'].sum()
df13
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
# a.Value based
df13.idxmax()
# Out:
# 'Technology'

# %%
# b.Quantity based
df14 = df.groupby('Category')['Quantity'].sum()
df14
# Out:
# Category
# Furniture           8028
# Office Supplies    22906
# Technology          6939
# Name: Quantity, dtype: int64

# %%
# b.Quantity based
df14.idxmax()
# Out:
# 'Office Supplies'

# %% [markdown]
# **TASK 12 : Find out the most and least sold product sub category from the store**

# %%
# a.Value based
df15 = df.groupby('Sub-Category')['Sales'].sum()
df15
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
# a.Value based
df15.idxmax()
# Out:
# 'Phones'

# %%
# b.Quantity based
df16 = df.groupby('Sub-Category')['Quantity'].sum()
df16
# Out:
# Sub-Category
# Accessories    2976
# Appliances     1729
# Art            3000
# Binders        5974
# Bookcases       868
# Chairs         2356
# Copiers         234
# Envelopes       906
# Fasteners       914
# Furnishings    3563
# Labels         1400
# Machines        440
# Paper          5178
# Phones         3289
# Storage        3158
# Supplies        647
# Tables         1241
# Name: Quantity, dtype: int64

# %%
# b.Quantity based
df16.idxmax()
# Out:
# 'Binders'
